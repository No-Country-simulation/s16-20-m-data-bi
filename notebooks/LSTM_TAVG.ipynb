# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

# %%
data = pd.read_csv('/content/CSV_LSTM.csv')

# Convertir la columna 'Date' al formato de fecha
data['DATE'] = pd.to_datetime(data['DATE'])
data_filtered1 = data[data['DATE'] > '2004-12-31']
# Establecer la columna 'date' como índice
data.set_index('DATE', inplace=True)

data
# Out:
#             TAVG
# DATE
# 1957-06-30     9
# 1957-07-01    10
# 1957-07-02    11
# 1957-07-03    13
# 1957-07-04    14
# ...          ...
# 2024-06-28    15
# 2024-06-29    12
# 2024-06-30    13
# 2024-07-01    21
# 2024-07-02    18
#
# [24122 rows x 1 columns]

# %%
# Trazar los datos de la serie temporal
plt.figure(figsize=(10, 6))
plt.plot(data)
plt.title('Temperatura promedio serie de tiempo')
plt.xlabel('Year')
plt.ylabel('Temperatura promedio')
plt.show()

# %%
# Normalizamos la data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Dividir los datos en conjuntos de train y prueba.
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 60  # Número de pasos de tiempo para mirar atrás
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
model = Sequential([
    LSTM(50, activation='relu', return_sequences=True, input_shape=(seq_length, 1)),
    Dropout(0.1),
    LSTM(50, activation='relu'),
    Dropout(0.1),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=100, batch_size=128, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 106/106 [==============================] - 42s 361ms/step - loss: 0.0434 - val_loss: 0.0110
# Epoch 2/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0124 - val_loss: 0.0110
# Epoch 3/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 4/100
# 106/106 [==============================] - 15s 138ms/step - loss: 0.0118 - val_loss: 0.0108
# Epoch 5/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0117 - val_loss: 0.0105
# Epoch 6/100
# 106/106 [==============================] - 15s 139ms/step - loss: 0.0112 - val_loss: 0.0102
# Epoch 7/100
# 106/106 [==============================] - 15s 143ms/step - loss: 0.0109 - val_loss: 0.0094
# Epoch 8/100
# 106/106 [==============================] - 15s 142ms/step - loss: 0.0102 - val_loss: 0.0087
# Epoch 9/100
# 106/106 [==============================] - 15s 140ms/step - loss: 0.0096 - val_loss: 0.0091
# Epoch 10/100
# 106/106 [==============================] - 15s 141ms/step - loss: 0.0093 - val_loss: 0.0078
# Epoch 11/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0088 - val_loss: 0.0074
# Epoch 12/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0085 - val_loss: 0.0071
# Epoch 13/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0085 - val_loss: 0.0073
# Epoch 14/100
# 106/106 [==============================] - 15s 142ms/step - loss: 0.0080 - val_loss: 0.0066
# Epoch 15/100
# 106/106 [==============================] - 15s 139ms/step - loss: 0.0080 - val_loss: 0.0064
# Epoch 16/100
# 106/106 [==============================] - 15s 143ms/step - loss: 0.0077 - val_loss: 0.0065
# Epoch 17/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0077 - val_loss: 0.0071
# Epoch 18/100
# 106/106 [==============================] - 15s 140ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 19/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0076 - val_loss: 0.0068
# Epoch 20/100
# 106/106 [==============================] - 17s 163ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 21/100
# 106/106 [==============================] - 17s 156ms/step - loss: 0.0074 - val_loss: 0.0063
# Epoch 22/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 23/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0074 - val_loss: 0.0062
# Epoch 24/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 25/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 26/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.0072 - val_loss: 0.0062
# Epoch 27/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0072 - val_loss: 0.0062
# Epoch 28/100
# 106/106 [==============================] - 17s 159ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 29/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 30/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0072 - val_loss: 0.0062
# Epoch 31/100
# 106/106 [==============================] - 15s 142ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 32/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 33/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 34/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 35/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 36/100
# 106/106 [==============================] - 15s 143ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 37/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 38/100
# 106/106 [==============================] - 18s 165ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 39/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 40/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 41/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 42/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 43/100
# 106/106 [==============================] - 15s 141ms/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 44/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 45/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 46/100
# 106/106 [==============================] - 16s 155ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 47/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 48/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 49/100
# 106/106 [==============================] - 15s 140ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 50/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 51/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 52/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 53/100
# 106/106 [==============================] - 16s 154ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 54/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 55/100
# 106/106 [==============================] - 18s 167ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 56/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 57/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 58/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 59/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 60/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 61/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 62/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 63/100
# 106/106 [==============================] - 17s 160ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 64/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 65/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 66/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 67/100
# 106/106 [==============================] - 15s 143ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 68/100
# 106/106 [==============================] - 17s 164ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 69/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 70/100
# 106/106 [==============================] - 17s 163ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 71/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 72/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 73/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 74/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 75/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 76/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 77/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 78/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 79/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 80/100
# 106/106 [==============================] - 16s 146ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 81/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 82/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 83/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 84/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 85/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 86/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 87/100
# 106/106 [==============================] - 17s 164ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 88/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 89/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 90/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 91/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 92/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 93/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 94/100
# 106/106 [==============================] - 17s 162ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 95/100
# 106/106 [==============================] - 16s 154ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 96/100
# 106/106 [==============================] - 15s 143ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 97/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 98/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 99/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 100/100
# 106/106 [==============================] - 15s 143ms/step - loss: 0.0060 - val_loss: 0.0059

# %%
# Asumimos que data y scaler ya están definidos

# Predecir usando el modelo entrenado
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Transformación inversa de las predicciones
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

# Convertir índice de data a datetime si no lo está
if not pd.api.types.is_datetime64_any_dtype(data.index):
    data.index = pd.to_datetime(data.index)

# Ajustar el índice de las predicciones
train_index = data.index[seq_length:seq_length+len(train_predictions)]
test_index = data.index[seq_length+len(train_predictions):seq_length+len(train_predictions)+len(test_predictions)]

# Plot predicciones
plt.figure(figsize=(10, 6))

# Plot data actual
plt.plot(data.index[seq_length:], data['TAVG'][seq_length:], label='Actual', color='blue')

# Plot predicciones de entramiento
plt.plot(train_index, train_predictions, label='Train Predictions', color='green')

# Plot predicciones de prueba
plt.plot(test_index, test_predictions, label='Test Predictions', color='orange')

plt.title('Temperatura promedio serie de tiempo')
plt.xlabel('Year')
plt.ylabel('Temperatura Promedio')
plt.legend()
plt.show()
# Out:
# 526/526 [==============================] - 13s 24ms/step
# 225/225 [==============================] - 6s 28ms/step

# %%
#Prediccion de Precipitacion
forecast_period = 180 #aca deberia ir los dias a predecir; si son 6 meses deberian ser 180, porque 30 dias x 6 meses=180 dias
forecast = []

# Utilice la última secuencia de los datos de prueba para hacer predicciones
last_sequence = X_test[-1]

for _ in range(forecast_period):
    # Remodelar la secuencia para que coincida con la forma de entrada del modelo
    current_sequence = last_sequence.reshape(1, seq_length, 1)
    # Predecir el siguiente valor
    next_prediction = model.predict(current_sequence)[0][0]
    # Agregar la predicción a la lista de pronósticos
    forecast.append(next_prediction)
    # Actualice la última secuencia eliminando el primer elemento y agregando el valor previsto
    last_sequence = np.append(last_sequence[1:], next_prediction)

# Transformación inversa de los valores pronosticados.
forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1))

# Convertir el índice de datos de prueba a fecha y hora si aún no lo está
if not pd.api.types.is_datetime64_any_dtype(data.index):
    data.index = pd.to_datetime(data.index)

# Plot de los valores pronosticados
plt.figure(figsize=(10, 6))
plt.plot(data.index[-len(test_data):], scaler.inverse_transform(test_data), label='Actual')

# Frecuencia diaria para el rango de fechas
forecast_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=forecast_period, freq='D')
plt.plot(forecast_dates, forecast, label='Forecast')

plt.title('Temperatura promedio serie de tiempo')
plt.xlabel('Year')
plt.ylabel('Temperatura promedio')
plt.legend()
plt.show()
plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
forecast_final = np.ravel(forecast) #aqui traspasé de formato array 2d a 1d
df_final = pd.DataFrame({"Fecha": forecast_dates,'Temperatura Promedio': forecast_final}) #fechas y forecast en un solo dataframe

# %%
df_final
# Out:
#          Fecha  Temperatura Promedio
# 0   2024-07-03             18.036943
# 1   2024-07-04             17.822269
# 2   2024-07-05             17.591600
# 3   2024-07-06             17.200602
# 4   2024-07-07             16.759008
# ..         ...                   ...
# 175 2024-12-25             14.606893
# 176 2024-12-26             14.606893
# 177 2024-12-27             14.606893
# 178 2024-12-28             14.606893
# 179 2024-12-29             14.606893
#
# [180 rows x 2 columns]

# %%
# Guardar el DataFrame como un archivo CSV
df_final.to_csv('predicciones.csv')

# Descargar el archivo CSV
#files.download('predicciones.csv') #esto es en caso de hacerlo en google colab
